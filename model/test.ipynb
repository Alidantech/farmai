# %% [markdown]
# # TEST THE DATA SETS

# %%
import pandas as pd

df = pd.read_csv("../data/crops_conditions.csv")

df.head()
# Out:
#                       Plant     Category Climate Conditions  \
# 0   Apple (Malus domestica)  Fruit Trees          Temperate
# 1                Asian pear  Fruit Trees          Temperate
# 2  Loquat (Japanese medlar)  Fruit Trees        Subtropical
# 3             Common medlar  Fruit Trees          Temperate
# 4                      Pear  Fruit Trees          Temperate
#
#   Temperature Range (°C) Light Intensity (hours/day) Relative Humidity (%)  \
# 0                   5-25                        6-12                 60-80
# 1                   5-25                        6-12                 60-80
# 2                  10-30                        8-12                 70-90
# 3                   5-25                        6-12                 60-80
# 4                   5-25                        6-12                 60-80
#
#   Annual Precipitation (mm) Wind Conditions Soil Moisture Soil Nutrients  \
# 0                  500-1500        Moderate         Moist  Well-balanced
# ...

# %%
df.shape
# Out:
# (183, 19)

# %%
locations_data = pd.read_csv("../data/locations_climate.csv")

locations_data
# Out:
#    Country         Region           County    Climate Conditions  \
# 0    Kenya        Nairobi  Nairobi Central             Temperate
# 1    Kenya        Nairobi         Kasarani             Temperate
# 2    Kenya        Nairobi         Lang'ata             Temperate
# 3    Kenya        Nairobi        Dagoretti             Temperate
# 4    Kenya          Coast          Mombasa              Tropical
# 5    Kenya          Coast           Kilifi              Tropical
# 6    Kenya          Coast             Lamu              Tropical
# 7    Kenya          Coast            Kwale              Tropical
# 8    Kenya         Nyanza           Kisumu              Tropical
# 9    Kenya         Nyanza         Homa Bay              Tropical
# 10   Kenya         Nyanza           Migori              Tropical
# 11   Kenya         Nyanza            Kisii  Subtropical Highland
# 12   Kenya        Western         Kakamega              Tropical
# ...

# %%
locations_data.shape
# Out:
# (40, 20)
